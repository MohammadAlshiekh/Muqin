# %%
import numpy as np

# load dialogues_and_speakers.npy
data = np.load('../Book Preprocessing/dialogues_and_speakers.npy')

for dialogue, speaker in data:
    print('Speaker:', speaker)
    print('Dialogue:', dialogue)

# create a list of the first 25 lines of dialogue
all_dialogue_lines = []

for dialogue, speaker in data:
    all_dialogue_lines.append((dialogue, speaker))
# Out:
# Speaker: المعلق
# Dialogue: مجنون ليلى الفصل الأول
# Speaker: المعلق
# Dialogue: (ساحة أمام خيام المهدي في حي بني عامر - مجلس من مجالس السمر في هذه
#             الساحة - فتية وفتيات من الحي يسمرون في أوائل الليل، وفي أيدي الفتيات صوف ومغازل يلهون
#             بها وهم يتحدثون — تخرج ليلى من خيام أبيها عند ارتفاع الستار ويدها في يد ابن ذريح)
# Speaker: المعلق
# Dialogue: ليلى
# Speaker: ليلى
# Dialogue: دعي الغزْلَ سلمى وحَيِّي معي منارَ الحِجَازِ فَتَى يَثْرِبِ
# Speaker: المعلق
# Dialogue: (تصافحه سلمى)
# Speaker: ليلى
# Dialogue:  ويا هِنْدُ هذا أديبُ الحِجازِ هلمِّي بمَقْدَمِهِ رَحِّبِي
# Speaker: المعلق
# Dialogue: (تصافحه هند ويحتفي به السامرون)
# Speaker: المعلق
# Dialogue: سعد
# Speaker: سعد
# Dialogue: أمن يثربٍ أنت آتٍ؟
# Speaker: المعلق
# Dialogue: ابن ذريح
# Speaker: ابن ذريح
# Dialogue: أجل من البلدِ القُدُس الطيِّب
# Speaker: المعلق
# Dialogue: ليلى
# Speaker: ليلى
# Dialogue: أيابنَ ذَريحٍ لقينا الغمام
# Speaker: المعلق
# Dialogue: هند
# Speaker: هند
# Dialogue: وطَافتْ بنا نَفَحَاتُ النبي
# Speaker: المعلق
# Dialogue: عبلة
# Speaker: المعلق
# Dialogue: (هامسة إلى سعد)
# Speaker: عبلة
# Dialogue: مَن ابْنُ ذَريحٍ؟
# Speaker: المعلق
# Dialogue: سعد
# Speaker: سعد
# Dialogue: فتًى ذِكرُه على مَشرِق الشمس والمغرب رَضيعُ الحُسَيْنِ عليه السلامُ وترْبُ الحُسَيْنِ من المكتبِ
# Speaker: المعلق
# Dialogue: عبلة
# Speaker: المعلق
# Dialogue: (إلى بشر ومشير إلى ابن ذريح)
# Speaker: عبلة
# Dialogue: أتسمَعُ بشرُ رضيعُ الْحُسَيْنِ فديْتُ الرضيعيْن والمُرضعهْ وأنت إذا ما ذكرنا الحسينَ تصاممتَ!
# Speaker: المعلق
# Dialogue: بشر
# Speaker: المعلق
# Dialogue: (هامسًا ومتلفتًا كأنما يخشى أن يسمعه أحد)
# Speaker: بشر
# Dialogue: لا جاهلًا موضِعَهْ ولكن أخاف امرأً أن يرى عليَّ التشيُّع أو يَسمَعَهْ أحِبُّ الحسينَ ولكنَّمَا لساني عليه وقلبي معهْ! حَبَسْتُ لسانيَ عن مدحه حِذارَ أميَّةَ أن تقطعه إذا الفتنةُ اضطرمتْ في البلاد ورُمْتَ النجاةَ فكُن إمَّعهْ!
# Speaker: المعلق
# Dialogue: ليلى
# Speaker: ليلى
# Dialogue: إبنَ ذريحٍ نحن في عُزْلَةٍ فهل على مُسْتفهِمٍ منك باسْ؟ دارُ النبيِّ كيف خلَّفْتَها؟ كيف تركتَ الأمرَ فيها يُساسْ
# Speaker: المعلق
# Dialogue: ابن ذريح
# Speaker: ابن ذريح
# Dialogue: تركتُها يا ليلَ مَضبوطةً يحكُمُها والٍ شديدُ المراسْ إن حديثَ الناس في يثربٍ همسٌ وخطوَ الناس فيها احتراس
# Speaker: المعلق
# Dialogue: ليلى
# Speaker: ليلى
# Dialogue: إبنَ ذريح لا تَجُرْ واقتصِدْ أحلامُ مَرْوانَ جبالٌ رَواسْ يؤسِّسُون المُلْكَ في بيتهم والْعُنْفُ والشدةُ عند الأساس
# Speaker: المعلق
# Dialogue: (تتضاحك الفتيات وتقول إحداهن لأخرى)
# Speaker: المعلق
# Dialogue: فتاة
# Speaker: فتاة
# Dialogue: ليلى على دينِ قيسٍ فحيثُ مال تميلُ! وكلُّ ما سرَّ قيسًا فعند ليلى جميلُ
# Speaker: المعلق
# Dialogue: ابن ذريح
# Speaker: ابن ذريح
# Dialogue: ما الذي أضحك مني الظَّبياتِ العامريَّهْ ألأَني أنا شِيعِيٌّ وليلى أمويَّهْ؟ إختلافُ الرأي لا يُفْسدُ للود قضيَّهْ
# Speaker: المعلق
# Dialogue: ليلى
# Speaker: ليلى
# Dialogue: أعِرْني سماعَك يابنَ ذريحٍ ولا تسمَعِ الطفلةَ الهاذيَهْ أتَيْتَ لنا اليومَ من يثربٍ فكيف ترى عالَمَ الباديَهْ أكنتَ من الدور أو في القصور ترى هذه القُبَّةَ الصافيَهْ؟ كـأن النجومَ على صدرها قلائدُ ماسٍ على غانيَهْ
# Speaker: المعلق
# Dialogue: هند
# Speaker: هند
# Dialogue: كفى يابنةَ الخال! هذا الحريرُ كثيرٌ على الرِّمَّة الباليَهْ تأمَّلْ تر البيدَ يابن ذريح كمقبرةٍ وَحْشَةٍ خاويَهْ سئمنا من البيدَ يابن ذريح ومن هذه العيشة الجافيَهْ ومن مُوقدِ النار في مَوْضِعٍ ومن حالب الشاة في ناحيَهْ وراغيةٍ من وراء الخيام تُجيبُ من الكَلأ الثاغيَة وأنتم بيثربَ أو بالعراق أو الشام في الغُرَف العاليَهْ مُغنِّيكمو مَعْبَدٌ والغريضُ وقيْنتُنا الضَّبُعُ العاويَهْ وقد تأكلون فُنُونَ الطُّهَاةِ ونأكل ما طَهتِ الماشيَهْ
# Speaker: المعلق
# Dialogue: ليلى
# Speaker: ليلى
# Dialogue: قد اعَتسَفتْ هندُ يابنَ ذريحٍ وكانت على مَهدها قاسيَهْ فما البيد إلا دِيارُ الكِرَامِ ومَنزلةُ الذِّمَمِ الوافيَهْ لها قُبْلَةُ الشمس عند البُزوغ وللحَضَرِ القُبْلَةُ الثانيَهْ ونحن الرياحينُ مِلْءَ الفضاء وهنَّ الرياحينُ في الآنيَهْ ويقتُلُنا العِشقُ والحاضراتُ يَقُمْنَ من العشق في عافيهْ ولم نصطَدِم بهُمُـوم الحياةِ ولم نَدرِ — لولا الهوى — ماهيَهْ وآنًا نخِفُّ لصَيْدِ الظباء وآنًا إلى الأسد الضاريَهْ
# Speaker: المعلق
# Dialogue: هند
# Speaker: المعلق
# Dialogue: (ساخرة)
# Speaker: هند
# Dialogue: وفي كل ناحيةٍ شاعرٌ يغنِّي بليلاهُ أو راويَهْ
# Speaker: المعلق
# Dialogue: (تحاول ليلى أن تمد رجلها فتتألم وتستغيث)
# Speaker: المعلق
# Dialogue: ليلى
# Speaker: ليلى
# Dialogue: قيسُ، إليَّ قيس
# Speaker: المعلق
# Dialogue: هند
# Speaker: هند
# Dialogue: ما دهاك ليلى ما الخبرْ
# Speaker: المعلق
# Dialogue: ليلى
# Speaker: ليلى
# Dialogue: أُحس رجلي خدِرت حتى كأنها الحَجَرْ
# Speaker: المعلق
# Dialogue: هند
# Speaker: هند
# Dialogue: قد صحتِ قيسُ مرتين
# Speaker: المعلق
# Dialogue: ليلى
# Speaker: ليلى
# Dialogue: أو ثلاثًا ما الضرر
# Speaker: المعلق
# Dialogue: هند
# Speaker: المعلق
# Dialogue: (متهكمة)
# Speaker: هند
# Dialogue: إسم الحبيبِ عندنا نذكره عند الخدر
# Speaker: المعلق
# Dialogue: ليلى
# Speaker: ليلى
# Dialogue: هند كفي دعابة إن هو الَّا اسمٌ حضر
# Speaker: المعلق
# Dialogue: (لنفسها)
# Speaker: ليلى
# Dialogue:  يا قيس ناجى باسمك القلبُ اللسان فعثَر
# Speaker: المعلق
# Dialogue: عبلة
# Speaker: المعلق
# Dialogue: (ضجرة)
# Speaker: عبلة
# Dialogue: أما سوى هذا الحديثِ شاغلُ؟ كيف ظللْتَ اليومَ يا منازلُ؟
# Speaker: المعلق
# Dialogue: منازل
# Speaker: المعلق
# Dialogue: (ضاحكًا)
# Speaker: منازل
# Dialogue: منازلُ اليوم كأمس هازلُ يشرَبُ أو يَطْعَمُ أو يُغازلُ!
# Speaker: المعلق
# Dialogue: هند
# Speaker: هند
# Dialogue: بخٍ! كذا فلتكنِ الحياةُ مُت يا بعير وانفُقي يا شاةُ انغَمست في الترف الرعاةُ!
# Speaker: المعلق
# Dialogue: ليلى
# Speaker: ليلى
# Dialogue: وكيف ظللت اليوم سعدُ؟ أهازلٌ كتِربك أم في صالحٍ ورشادِ!
# Speaker: المعلق
# Dialogue: سعد
# Speaker: سعد
# Dialogue: بل الجدُّ يا ليلى سبيلي وديْدني حياتي بِوادٍ والمُجونُ بواد صحبتُ زيادًا طول يومي تلقفًا لأشعار قيسٍ من لسان زياد وإن زيادًا — منذ كان — لرائحٌ علينا بشعر العامريِّ وغاد ولولا زيادٌ ما تمثَّل حاضرٌ بأشعار قيسٍ أو ترنم باد
# Speaker: المعلق
# Dialogue: (يبدو على ليلى شيء من الزهو فتتهامس الفتيات)
# Speaker: المعلق
# Dialogue: سلمى
# Speaker: سلمى
# Dialogue: انظري هند تريْ ليلى اكتست زهوًا وكبرَا وتعالت كابنةِ النعمان أو كابنة كسرى!
# Speaker: المعلق
# Dialogue: هند
# Speaker: هند
# Dialogue: لمَ لا سلمى، ألم يرفع لها المجنونُ ذكرَا؟
# Speaker: المعلق
# Dialogue: عبلة
# Speaker: عبلة
# Dialogue: لِمْ إذن يا هند من قيسٍ ومما قال تَبْرَا؟
# Speaker: المعلق
# Dialogue: هند
# Speaker: هند
# Dialogue: عَبَثُ النِّسوةِ! إنا نحن بالنسوة أدرى!
# Speaker: المعلق
# Dialogue: سلمى
# Speaker: سلمى
# Dialogue: سلوا الآن بشرًا فيم أنفق يومَه؟
# Speaker: المعلق
# Dialogue: أصوات
# Speaker: أصوات
# Dialogue: سلوه
# Speaker: المعلق
# Dialogue: هند
# Speaker: هند
# Dialogue: سلي يا ليلَ عن يومه بِشرَا
# Speaker: المعلق
# Dialogue: ليلى
# Speaker: ليلى
# Dialogue: وهَل يومهُ إلا شئونٌ كأمسِه من الصيد؟
# Speaker: المعلق
# Dialogue: هند
# Speaker: هند
# Dialogue: إن الصيدَ لذتُه الكبرى
# Speaker: المعلق
# Dialogue: بشر
# Speaker: بشر
# Dialogue: نعم هو ملهايَ الذي لا أمَله ولا النفسُ تُعطَى عن تناوله صبرا ولو كان عيشي في قصور أميَّةٍ لعَلَّمْتُ فنَّ الصيد فتيانهَا الزهرا وما أنا صيَّادُ الأرانب مثلَهم ولكن على حيَّاتِهِ ألِجُ القَفْرَا
# Speaker: المعلق
# Dialogue: ليلى
# Speaker: ليلى
# Dialogue: إذن هاتِ واصدُقْ بشرُ في القول مرَّةً ولا تخترعْ أو تَبْنِ من حَجَرٍ قصرا!
# Speaker: المعلق
# Dialogue: بشر
# Speaker: بشر
# Dialogue: دعي عنكِ هذا السُّخْرَ يا ليلَ واسمعي
# Speaker: المعلق
# Dialogue: ليلى
# Speaker: ليلى
# Dialogue: تحدَّثْ فلا واللهِ لم أُضْمِر السُّخرا
# Speaker: المعلق
# Dialogue: بشر
# Speaker: بشر
# Dialogue: بكَرتُ كدأبي اليومَ أبغي قنيصةً ومَن يتصيَّدْ يحسب الغُنْمَ والخُسرا (رأيت غزالًا يرتعي وَسْط روضة فقلت أرى ليلى تَراءتْ لنا ظُهرًا)
# Speaker: المعلق
# Dialogue: هند
# Speaker: المعلق
# Dialogue: (مشيرة إلى ليلى)
# Speaker: هند
# Dialogue: وأيَّ الليالي بشرُ آنست؟ هذه
# Speaker: المعلق
# Dialogue: بشر
# Speaker: بشر
# Dialogue: إذا شئتِ — أو هاتيكِ — أو حُرَّةً أخرى فقلتُ له يا ظبيُ لا تخشَ حادثًا
# Speaker: المعلق
# Dialogue: (فإنك لي جارٌ ولا ترهبِ الدَّهْرَا)
# Speaker: بشر
# Dialogue:  (فما راعني إلا وذئبٌ قد انتحى فأعلق في أحشائه الناب والظُّفرا) (ففوَّقتُ سهمي في كَتومٍ غمستُها فخالط سهمي مهجةَ الذئبِ والنحرا)
# Speaker: المعلق
# Dialogue: ليلى
# Speaker: المعلق
# Dialogue: (ضاحكة)
# Speaker: ليلى
# Dialogue: أخي بشرُ لا شُلتْ يمينُك من يدٍ ولا فَضَّ فاك الصبحُ والليلُ ما كرَّا سمعنا بإِقدام اللصوص وفتكهم فلم نر أدهى منك فتكًا ولا أجرا! ووالله لم تغضب لظبي ولم تثبْ بذئب ولم تُعمِلْ خيالًا ولا فكرا أخذتَ فلم تترك لقيسٍ بضاعةً سرقتَ لعمري الظبيَ والذئبَ والشعرا!
# Speaker: المعلق
# Dialogue: (ضحك من الجميع)
# Speaker: ليلى
# Dialogue:  حديثُ الظبيِ والذئبِ وقيسٍ لستُ أنساه زيادٌ عنه نبَّاني ولا ينبيك إلَّاه رأى قيسٌ على رابـية ظبيًا فناداه فألقى الظبيُ أذْنَيْهِ ومسَّ الأرضَ قرناه
# Speaker: المعلق
# Dialogue: (ثم تقول في لوعة وصوت مخفوض وكأنما تحدث نفسها)
# Speaker: ليلى
# Dialogue:  برُوحي قيسُ! هل راحت ظباءُ القاع تهواه؟ وهل يَرثي له الريمُ ولا أرثي لبلواه؟
# Speaker: المعلق
# Dialogue: (تسترسل في حديثها الأول)
# Speaker: ليلى
# Dialogue:  على فيه من العُشْبِ بقايا صبغت فاه رأى في جيده قيسٌ وفي عينيه ليلاه فبينا هو في الشوقِ وفي نشوة ذكراه حبا الذئبُ من الوادي إلى الظبي فأرداه تغدى بحَشا الظَّبي غَداءً ما تهنَّاه رماه قيس في المقتـل بالسهم فأصماه
# Speaker: المعلق
# Dialogue: بشر
# Speaker: المعلق
# Dialogue: (مندفعًا بحماسة!)
# Speaker: بشر
# Dialogue: أجل يا ليلَ! ما قلتِ سوى شيءٍ شهِدناه وإن لم تذكري القبرَ ولا كيف خططناه حفرنا القبرَ للظبيِ وقمنا فدفناه وصلَّينا على الميْتِ وبالدمع سقيناه فقولوا ولتقل ليلى معي يرحمُه الله!
# Speaker: المعلق
# Dialogue: أصوات
# Speaker: المعلق
# Dialogue: (بين الضحك والسخرية)
# Speaker: أصوات
# Dialogue: أجل بشرُ! أجل بشرُ! أجل يرحمه الله!
# Speaker: المعلق
# Dialogue: ابن ذريح
# Speaker: ابن ذريح
# Dialogue: بشرُ كفى هزلًا وتخليطًا كفى ويابنةَ العم مضى الليلُ سُدى أرسلني قيسُ فلو أخبرتني متى متى بأمر قيسٍ يُعتنى؟ بتنا نخافُ أن يجِلَّ خطبُه وتبلغَ البلوى بقيسٍ المَدى وقيسُ يا ليلى وإن لم تجهلي زين الشباب وابنُ سيد الحمى لم ندرِ في حيِّك أو في حيِّه فتى حكاه نسبًا ولا غنى ولا جمالًا، وهنا (يا ليلَ) ما تريْنَ أنتِ لا الذي نحن نرى
# Speaker: المعلق
# Dialogue: بشر
# Speaker: المعلق
# Dialogue: (ساخرًا)
# Speaker: بشر
# Dialogue: بخٍ بَخٍ! إبنُ ذريح خاطبٌ
# Speaker: المعلق
# Dialogue: ابن ذريح
# Speaker: ابن ذريح
# Dialogue: أسكت فلست للمروءات أخَا!
# Speaker: المعلق
# Dialogue: ليلى
# Speaker: المعلق
# Dialogue: (غاضبة)
# Speaker: ليلى
# Dialogue: فيم هذا الكلامُ يا بنَ ذريحٍ؟
# Speaker: المعلق
# Dialogue: ابن ذريح
# Speaker: ابن ذريح
# Dialogue: إتقي اللهَ واقصِدي في التجني
# Speaker: المعلق
# Dialogue: ليلى
# Speaker: ليلى
# Dialogue: ما تجنَّيت
# Speaker: المعلق
# Dialogue: ابن ذريح
# Speaker: ابن ذريح
# Dialogue: بل ظلمت، دعيني أُحسن الذَّودَ عن صديقي وخِدني
# Speaker: المعلق
# Dialogue: ليلى
# Speaker: ليلى
# Dialogue: أنا أَوْلى به وأحنى عليه لو يُداوَى برحمتي والتحنِّي يعلمُ الله وحده ما لقيس من هوًى في جوانحي مستكِنِّ إنني في الهوى وقيسًا سواءٌ دَنُّ قيس من الصبابة دَنِّي أنا بين اثنتين كلتاهما النا ر فلا تَلْحَى ولكن أعِنِّي بين حرصي على قَداسة عرضي واحتفاظي بمن أُحبُّ وضَنِّي صنتُ منذ الحداثة الحبَّ جهدي وهو مستهترُ الهوى لم يَصُنِّي قد تغنى بليلة الغَيْلِ، ماذا كان بالغيل بين قيس وبيني؟ كل ما بيننا سلامٌ وردٌّ بين عين من الرفاق وأُذن وتبسَّمتُ في الطريق إليه ومضى شأنه وسرتُ لشأني
# Speaker: المعلق
# Dialogue: (تهيب بالسامرين وقد بلغ بها الغضب أقصاه)
# Speaker: ليلى
# Dialogue:  أَوْغل الليلُ فلنقمْ
# Speaker: المعلق
# Dialogue: ابن ذريح
# Speaker: المعلق
# Dialogue: (متوسلًا)
# Speaker: ابن ذريح
# Dialogue: بل رويدًا واسمعي (ليلَ)
# Speaker: المعلق
# Dialogue: ليلى
# Speaker: ليلى
# Dialogue: خلِّ عَنِّيَ دعني!
# Speaker: المعلق
# Dialogue: (تدخل خباءها بينما ينفض السامرون فلا يتثاقل منهم في القيام إلا
#                 منازل — الهرج والأسف يسودان الجميع)
# Speaker: المعلق
# Dialogue: بشر
# Speaker: بشر
# Dialogue: انفضَّ سامرُ ليلى وكان حَفْلًا كريمَا
# Speaker: المعلق
# Dialogue: سعد
# Speaker: سعد
# Dialogue: قد فَضَّه ابن ذريح ففض عِقدا نظيمَا أثار ليلى فهاجت كما تنفِّر رِيمَا ترى أتُبْغِضُ قيسًا
# Speaker: المعلق
# Dialogue: ابن ذريح
# Speaker: ابن ذريح
# Dialogue: لا تقلبوا الحبَّ بغضَا ليلى العشيةَ غضبى ويُصبح الصبحُ ترضى
# Speaker: المعلق
# Dialogue: سعد
# Speaker: سعد
# Dialogue: أنعم (مُنَازِ) مساءً
# Speaker: المعلق
# Dialogue: منازل
# Speaker: منازل
# Dialogue: نعمت سعدُ مساء
# Speaker: المعلق
# Dialogue: هند
# Speaker: هند
# Dialogue: بشرُ مُسِّيتَ بخيرٍ
# Speaker: المعلق
# Dialogue: بشر
# Speaker: بشر
# Dialogue: أنعمي هندُ مساءَ
# Speaker: المعلق
# Dialogue: هند
# Speaker: هند
# Dialogue: نحن يحوينا طريقٌ فامض بلّغني الخباءَ
# Speaker: المعلق
# Dialogue: سعد
# Speaker: المعلق
# Dialogue: (ضاحكًا)
# Speaker: سعد
# Dialogue: احذري يا هند منه!
# Speaker: المعلق
# Dialogue: هند
# Speaker: هند
# Dialogue: أنا لا أخشى اعتداء قد عرفتم وعرفنا كيف يصطاد الظباء!
# Speaker: المعلق
# Dialogue: (تسمع ضحكاتهم من أقصى الطريق بينما يظهر قيس وزياد من جانب المسرح
#                 الآخر)
# Speaker: المعلق
# Dialogue: قيس
# Speaker: قيس
# Dialogue: سجا الليل حتى هاج لي الشعرَ والهوى وما البيدُ إلا الليلُ والشعرُ والحبُّ ملَأْت سماءَ البيدِ عشقًا وأرضَها وحُمِّلْتُ وحدي ذلك العشقَ يا ربُّ ألَمَّ على أبيات ليلى بيَ الهوى وما غيرَ أشواقي دليلٌ ولا ركبُ وباتت خيامي خُطوة من خيامها فلم يَشفني منها جوار ولا قرب إذا طاف قلبي حولها جُنَّ شوقُه كذلك يُطغِي الغُلةَ المنهلُ العذب يحن إذا شطَّت ويصبو إذا دنت فيا ويح قلبي كم يحن وكم يصبو وارسلني أهلي وقالوا امض فالتمس لنا قبسًا من أهل ليلى وما شبُّوا عفا الله عن ليلى لقد نؤتُ بالذي تحمَّلَ من ليلى ومن نارها القلب
# Speaker: المعلق
# Dialogue: منازل
# Speaker: المعلق
# Dialogue: (وقد سمع همهمة الصوت ورأى شبحيهما في الظلام)
# Speaker: منازل
# Dialogue: أرى شبحًا مقبلًا في الظلام وأسمع همهمة في الدجى هو ابن الملوَّحِ دلَّ الهُزالُ عليه ونمَّ اضطراب الخُطا عدوِّي المبين وما بيننا ولا بين صاغِيتيْنَا روى شعرَه البدو والحاضرون وشعريَ ليس له من روى وهام بليلى وهامت به لقد كنت أولى بهذا الهوى تشرَّد مستعظَمًا في البلاد وجُنَّ فما ازداد إلَّا نُهى وإني لأُبدي إليه الوداد وأخفي له في الضلوع القِلى وأحسُدُه حسدًا ما علمت أقيسُ الشقيُّ به أم أنا
# Speaker: المعلق
# Dialogue: (يتقدم منهما خطوات)
# Speaker: منازل
# Dialogue:  من الراكبُ الليل؟ قيسٌ أخي؟
# Speaker: المعلق
# Dialogue: قيس
# Speaker: قيس
# Dialogue: منازل؟ ما أعجبَ الملتقى!
# Speaker: المعلق
# Dialogue: منازل
# Speaker: منازل
# Dialogue: أقيسًا أرى في ظلال البيوت؟ وعهدي بقيس حليفَ الفلا
# Speaker: المعلق
# Dialogue: قيس
# Speaker: قيس
# Dialogue: منازل، من أين؟
# Speaker: المعلق
# Dialogue: منازل
# Speaker: منازل
# Dialogue: من عندِها من السمر الممتِع المشتَهى
# Speaker: المعلق
# Dialogue: قيس
# Speaker: المعلق
# Dialogue: (حنقًا)
# Speaker: قيس
# Dialogue: أمن عند ليلى تجرُّ الذيول حديث لَعمرُ أبي مفترى
# Speaker: المعلق
# Dialogue: منازل
# Speaker: منازل
# Dialogue: بل الصدقُ ما قلتُ يابن الملوَّ ح
# Speaker: المعلق
# Dialogue: قيس
# Speaker: قيس
# Dialogue: إخسأ متى قلت صدقًا متى؟ وما كنت تصنع؟
# Speaker: المعلق
# Dialogue: منازل
# Speaker: المعلق
# Dialogue: (ساخرًا)
# Speaker: منازل
# Dialogue: ما يصنعون لهوت لعمريَ فيمن لها وسامر ليلى كثير الزِّحام فلست تعدُّ شباب الحِمى وليلى تُفيضُ على من تشاء رضاها وتحرمُه من تشا
# Speaker: المعلق
# Dialogue: زياد
# Speaker: المعلق
# Dialogue: (مغضبًا)
# Speaker: زياد
# Dialogue: منازل، قيسُ، سبيلكَ قيس! وكِلْ ليَ تأديبَ هذا الفتى
# Speaker: المعلق
# Dialogue: منازل
# Speaker: المعلق
# Dialogue: (وقد أخذ بتلابيبه)
# Speaker: منازل
# Dialogue: تؤدبُني زيادُ وأنت ظل لمجنون وراوية لهاذي وتزعمُ أنني نِدٌّ لقيس رضِيت من المصائب غيرَ هذي!
# Speaker: المعلق
# Dialogue: زياد
# Speaker: زياد
# Dialogue: من قال ذا؟ أنت لقيس نِدُّ لم يبق فيكِ يا حياةُ جِدُّ إمض بنا ناحيةً يا وغد!
# Speaker: المعلق
# Dialogue: (يجره إلى حيث تسمع أصواتهما من بعيد ثم تختفي فيقبل قيس على خباء
#                 ليلى وينادي)
# Speaker: المعلق
# Dialogue: قيس
# Speaker: قيس
# Dialogue: ليلى!
# Speaker: المعلق
# Dialogue: المهدي
# Speaker: المعلق
# Dialogue: (خارجًا من الخباء)
# Speaker: المهدي
# Dialogue: من الهاتف الداعي؟ أقيس أرى؟ ماذا وقوفُك والفتيان قد ساروا
# Speaker: المعلق
# Dialogue: قيس
# Speaker: المعلق
# Dialogue: (خجلًا)
# Speaker: قيس
# Dialogue: ما كنتُ يا عمُّ فيهم
# Speaker: المعلق
# Dialogue: المهدي
# Speaker: المعلق
# Dialogue: (دهشًا)
# Speaker: المهدي
# Dialogue: أين كنت إذن؟!
# Speaker: المعلق
# Dialogue: قيس
# Speaker: قيس
# Dialogue: في الدار حتى خَلتْ من نارنا الدار ما كان من حطب جَزْلٍ بساحتها أوْدى الرياحُ به والضيفُ والجار
# Speaker: المعلق
# Dialogue: المهدي
# Speaker: المعلق
# Dialogue: (مناديًا)
# Speaker: المهدي
# Dialogue: ليلى — انتظر قيس — ليلى
# Speaker: المعلق
# Dialogue: ليلى
# Speaker: المعلق
# Dialogue: (من أقصى الخباء)
# Speaker: ليلى
# Dialogue: ما وراء أبي؟
# Speaker: المعلق
# Dialogue: المهدي
# Speaker: المهدي
# Dialogue: هذا ابن عمِّك ما في بيتهم نار
# Speaker: المعلق
# Dialogue: (تظهر ليلى على باب الخباء)
# Speaker: المعلق
# Dialogue: ليلى
# Speaker: ليلى
# Dialogue: قيس ابن عمي عندنا يا مرحبًا يا مرحبَا
# Speaker: المعلق
# Dialogue: قيس
# Speaker: قيس
# Dialogue: مُتِّعتِ ليلى بالحيا ة وبَلَغْتِ الأَرَبَا
# Speaker: المعلق
# Dialogue: ليلى
# Speaker: المعلق
# Dialogue: (تنادي جاريتها بينما يختفي أبوها في الخباء)
# Speaker: ليلى
# Dialogue: عفراء
# Speaker: المعلق
# Dialogue: عفراء
# Speaker: المعلق
# Dialogue: (ملبية نداء مولاتها)
# Speaker: عفراء
# Dialogue: مولاتي
# Speaker: المعلق
# Dialogue: ليلى
# Speaker: ليلى
# Dialogue: تعالَيْ نقضِ حقًّا وَجَبَا خذي وعاءً واملئيه لابنِ عمِّي حَطَبَا
# Speaker: المعلق
# Dialogue: (تخرج عفراء وتتبعها ليلى)
# Speaker: المعلق
# Dialogue: قيس
# Speaker: قيس
# Dialogue: بالروح ليلى قضت لي حاجةً عرضت ما ضرها لو قضت للقلب حاجاتِ مضت لأبياتها ترتاد لي قبسًا والنار يا رُوحَ قيسٍ ملءُ أبياتي كم جئتُ ليلى بأسباب ملفَّقَةٍ ما كان أكثر أسبابي وعلاتي
# Speaker: المعلق
# Dialogue: (تدخل ليلى)
# Speaker: المعلق
# Dialogue: ليلى
# Speaker: ليلى
# Dialogue: قيس
# Speaker: المعلق
# Dialogue: قيس
# Speaker: قيس
# Dialogue: ليلى بجانبي كلُّ شيء إذن حضَرْ
# Speaker: المعلق
# Dialogue: ليلى
# Speaker: ليلى
# Dialogue: جمعتنا فأحسنت ساعةٌ تَفْضُلُ العُمُرْ
# Speaker: المعلق
# Dialogue: قيس
# Speaker: قيس
# Dialogue: أتجدِّين؟
# Speaker: المعلق
# Dialogue: ليلى
# Speaker: ليلى
# Dialogue: ما فؤا دي حديدٌ ولا حجرْ لك قلبٌ فسله يا قيس ينْبِئْكَ بالخبرْ قدْ تحملتُ في الهوى فوق ما يحتمل البشرْ
# Speaker: المعلق
# Dialogue: قيس
# Speaker: قيس
# Dialogue: لستُ ليلاي داريًا كيف أشكو وأَنفجِرْ؟ أشرح الشوقَ كله أم من الشوق أختصِرْ؟
# Speaker: المعلق
# Dialogue: ليلى
# Speaker: ليلى
# Dialogue: نبِّني قيسُ ما الذي لك في البيد من وطرْ؟ لك فيها قصائدٌ جاوزَتْها إلى الحضرْ كلُّ ظبي لقيته صُغت في جيده الدررْ أتُرى قد سلوْتنا وعشقتَ المَها الأُخرْ؟
# Speaker: المعلق
# Dialogue: قيس
# Speaker: قيس
# Dialogue: غرت ليلى من المهَا والمها منك لم تَغَرْ حبَّب البيدَ أنها بكِ مصبوغَةُ الصُّوَرْ لست كالغِيدِ لا ولا قمرُ البيد كالقمرْ
# Speaker: المعلق
# Dialogue: ليلى
# Speaker: المعلق
# Dialogue: (وقد رأت النار تكاد تصل إلى كم قيس)
# Speaker: ليلى
# Dialogue: ويحَ عينيَّ ما أرى! قيس
# Speaker: المعلق
# Dialogue: قيس
# Speaker: قيس
# Dialogue: ليلى
# Speaker: المعلق
# Dialogue: ليلى
# Speaker: المعلق
# Dialogue: (مشفقة)
# Speaker: ليلى
# Dialogue: خذِ الحذرْ!
# Speaker: المعلق
# Dialogue: قيس
# Speaker: المعلق
# Dialogue: (غير آبه إلا لما كان فيه من نجوى)
# Speaker: قيس
# Dialogue: رُبَّ فجر سألتُه هل تنفستِ في السحَرْ ورياح حسِبتُها جرَّرَت ذيلَك العطِرْ وغزالٍ جُفونهُ سرقت عينكِ الحَوَرْ
# Speaker: المعلق
# Dialogue: ليلى
# Speaker: ليلى
# Dialogue: إطرح النارَ يا فتى أنت غادٍ على خطرْ لهبُ النار قيسُ في كمِّك الأيمن انتشرْ
# Speaker: المعلق
# Dialogue: قيس
# Speaker: المعلق
# Dialogue: (مستمرًّا بعد أن رمى النار من يديه)
# Speaker: قيس
# Dialogue: وذئابٍ أرقَّ يا ليلُ من أهلِك الغُيُرْ أنِستْ بي ومرَّغت في يدي الناب والظفُرْ
# Speaker: المعلق
# Dialogue: ليلى
# Speaker: ليلى
# Dialogue: ويح قيسٍ تحرقت راحتاه وما شَعَرْ
# Speaker: المعلق
# Dialogue: قيس
# Speaker: قيس
# Dialogue: أنت أججتِ في الحَشا لاعجَ الشوقِ فاستَعَرْ ثم تخشَيْنَ جمرةً تأكلُ الجلد والشَّعَرْ
# Speaker: المعلق
# Dialogue: (يترنح قيس في موقفه وتظهر عليه بوادر الإغماء)
# Speaker: المعلق
# Dialogue: ليلى
# Speaker: ليلى
# Dialogue: فِدَاك أبي قيس ماذا دَهاك؟ تكلم، أبِن قيس، ماذا تَجِدْ
# Speaker: المعلق
# Dialogue: قيس
# Speaker: قيس
# Dialogue: أحسُّ بعينيَّ قد غامتا وساقيَّ لا تحمِلان الجسَدْ
# Speaker: المعلق
# Dialogue: (يخر صريعًا إلى الأرض فتتلقاه على صدرها صارخة)
# Speaker: المعلق
# Dialogue: ليلى
# Speaker: ليلى
# Dialogue: يا لأبي للجارْ قيس صريعُ النارْ ملقًى بصَحن الدارْ!
# Speaker: المعلق
# Dialogue: (يخرج أبوها من الخباء على صوت استغاثتها)
# Speaker: ليلى
# Dialogue:  أبي ها أنت ذا جئت أغِثنا أبتي أدركْ لقد حُرِّق بالنارِ فما يصحو إذا حُرِّك
# Speaker: المعلق
# Dialogue: المهدي
# Speaker: المهدي
# Dialogue: يرانا الناسُ يا ليلى
# Speaker: المعلق
# Dialogue: ليلى
# Speaker: ليلى
# Dialogue: أبي انْفِ الناسَ من فكرك هنا لا تقعُ العيْنُ على غيري ولا غيرك ولا يَطْلُعُ إنسانٌ على سري ولا سِرك ولا أجدر من قيس بإشفاقك أو برك أبي صدريَ لا يقوى فأسندْه إلى صدرك
# Speaker: المعلق
# Dialogue: المهدي
# Speaker: المعلق
# Dialogue: (وهو يتلقى عنها جسد قيس ويحاول إنعاشه)
# Speaker: المهدي
# Dialogue: رعاك اللهُ يا ليلى وكافاك على صبرك أخافُ الناسَ في أمري وأخشى القلبَ في أمرك وكم داريتُ يا ليلى وكم مهَّدْتُ من عذرك ولست الوالدَ القاسي ولا الطامعَ في مهرك
# Speaker: المعلق
# Dialogue: (يناجي قيسًا في غيبوبته)
# Speaker: المهدي
# Dialogue:  أبا المهديِّ عوفيتَ ويا بورك في عمرك أراني شعرُكَ الويلَ وما أروي سوى شعرك كما لَذَّ على الكُرهِ كلامُ الله للمشرك!
# Speaker: المعلق
# Dialogue: (يتحرك قيس ويبدو عليه كـأنما يفيق فيناديه)
# Speaker: المهدي
# Dialogue:  قيس
# Speaker: المعلق
# Dialogue: قيس
# Speaker: المعلق
# Dialogue: (يحاول الوقوف فتسنده ليلى)
# Speaker: قيس
# Dialogue: لبَّيك عمِّ
# Speaker: المعلق
# Dialogue: المهدي
# Speaker: المهدي
# Dialogue: حسبُكَ فاذهبْ لا تطأْ لي بعد العشيَّةِ دارَا
# Speaker: المعلق
# Dialogue: ليلى
# Speaker: ليلى
# Dialogue: أبتي لا تَجُر على قيسَ
# Speaker: المعلق
# Dialogue: المهدي
# Speaker: المهدي
# Dialogue: لِمْ لا إن قيسًا على القرابة جارَا
# Speaker: المعلق
# Dialogue: ليلى
# Speaker: ليلى
# Dialogue: أبتي ما تراه كالفَنن الذا وي نُحولًا وكالمَغيب اصفرارَا؟ وتأملْ رداءَه ويديْه تجد النارَ أو ترَ الآثارَا أبتي دَعْهُ يَسترحْ
# Speaker: المعلق
# Dialogue: المهدي
# Speaker: المهدي
# Dialogue: بل دعينا لا تزيدي يا ليلَ سُخطي انفجارَا
# Speaker: المعلق
# Dialogue: قيس
# Speaker: قيس
# Dialogue: حسبُ يا ليلَ، حسبُ ذلًّا لعمِّي وكفى حِلفةً له واعتذارَا عمُّ ماذا جنيت؟
# Speaker: المعلق
# Dialogue: ليلى
# Speaker: ليلى
# Dialogue: ماذا جنى قيس؟
# Speaker: المعلق
# Dialogue: المهدي
# Speaker: المهدي
# Dialogue: نسيتِ الرُّوَاةَ والأخبارَا
# Speaker: المعلق
# Dialogue: قيس
# Speaker: قيس
# Dialogue: إنهم يأفكِون يا عمِّ
# Speaker: المعلق
# Dialogue: المهدي
# Speaker: المهدي
# Dialogue: والغيلُ أليلًا غشِيتَه أم نهارَا؟ ما الذي كان ليلةَ الغَيْل حتى قلتَ فيها النَّسيبَ والأشعارَا؟
# Speaker: المعلق
# Dialogue: قيس
# Speaker: قيس
# Dialogue: لم تكنْ وحدَها ولا كنتُ وحدي إنما نحن فِتيةٌ وَعَذارَى جمعتْنا خمائلُ الغيل بالليل كما يجمعُ الحمى السُّمَّارَا ليسَ غيرَ السلامِ ثم افترَقنا ذهبتْ يمنةً وسِرتُ يسارَا
# Speaker: المعلق
# Dialogue: المهدي
# Speaker: المهدي
# Dialogue: إِمض يا قيس إمض لا تكسُ ليلى كلَّ حينٍ فضيحةً وشنارَا فكأني بقصة النار تُروى وكأني بذلك الشعر سارَا وكأني ارتديتُ في الحي ذلًّا وتجللتُ في القبائل عارَا إمض قيسُ امضِ
# Speaker: المعلق
# Dialogue: قيس
# Speaker: قيس
# Dialogue: عمُّ رفقًا بليلى وبقيسٍ ولا تكن جبارَا الحذَارَ الحِذَارَ من غضب الله ومن سُخطه الحذار الحذارَا
# Speaker: المعلق
# Dialogue: المهدي
# Speaker: المهدي
# Dialogue: إِمض قيس امض جئت تطلب نارًا أم ترى جئتَ تُشعلُ البيتَ نارَا؟
# Speaker: المعلق
# Dialogue: (يخرج قيس)

# %%
characters = set()
for dialogue, speaker in all_dialogue_lines:
    characters.add(speaker)

# %%
# print characters not in character_id dict

character_id = {
    "المعلق": "nPczCjzI2devNBz1zQrb",
    "قيس": "SOYHLrjzK2X1ezoPC6cr",
    "ليلى": "XB0fDUnXU5powFXDhCwa",
    "المهدي": "2EiwWnXFnvU5JabPnv8n",
    "زياد": "VR6AewLTigWG4xSOukaG",
    "سعد": "iP95p4xoKVk53GoZ742B",
    "بشر": "iP95p4xoKVk53GoZ742B",
    "ابن ذريح": "N2lVS1w4EtoT3dr4eOWO",
    "عفراء": "Xb7hH8MSUJpSbSDYk0k2",
    "سلمى": "Xb7hH8MSUJpSbSDYk0k2",
    "هند": "Xb7hH8MSUJpSbSDYk0k2",
    "عبلة": "Xb7hH8MSUJpSbSDYk0k2",
    "فتاة": "Xb7hH8MSUJpSbSDYk0k2",
    "أصوات": "nPczCjzI2devNBz1zQrb",
    "منازل": "iP95p4xoKVk53GoZ742B"
}


for character in characters:
    if character not in character_id:
        print('Character not in character_id:', character)

# %%
import requests
import json
import os

# Load API keys from a JSON file
with open('api_keys.json') as file:
    api_keys = json.load(file)

# Convert the API keys dictionary to a list of keys
api_key_list = list(api_keys.values())

# Function to update the API key in headers
def update_api_key(headers, new_key):
    headers["xi-api-key"] = new_key
    return headers

headers = {
    "xi-api-key": api_key_list[0],  # Start with the first API key
    "Content-Type": "application/json"
}

if not os.path.exists('chapter_1'):
    os.mkdir('chapter_1')

for audioNum, (dialogue, speaker) in enumerate(all_dialogue_lines):
    payload = {
        "model_id": "eleven_multilingual_v1",
        "text": f"{dialogue}"
    }
    
    if speaker not in character_id:
        print(f"Skipping line {audioNum+1} due to missing character ID.")
        continue

    url = f"https://api.elevenlabs.io/v1/text-to-speech/{character_id[speaker]}"

    for api_key in api_key_list:
        response = requests.post(url=url, json=payload, headers=update_api_key(headers, api_key))

        if response.status_code == 200:
            with open(f"chapter_1/{audioNum+1}-{speaker}.mp3", 'wb') as audio_file:
                audio_file.write(response.content)
            print(f"Audio file {audioNum+1} saved successfully.")
            break  # Exit the API key loop on success
        else:
            print(f"Retry with next API key due to status code:", response.status_code)
    else:
        # This part is executed only if the loop was not broken
        print(f"Failed to retrieve audio {audioNum+1}. Tried all API keys.")
        break  # Exit the dialogue loop since all keys failed
# Out:
# Audio file 1 saved successfully.
# Audio file 2 saved successfully.
# Audio file 3 saved successfully.
# Audio file 4 saved successfully.
# Audio file 5 saved successfully.
# Audio file 6 saved successfully.
# Audio file 7 saved successfully.
# Audio file 8 saved successfully.
# Audio file 9 saved successfully.
# Audio file 10 saved successfully.
# Audio file 11 saved successfully.
# Audio file 12 saved successfully.
# Audio file 13 saved successfully.
# Audio file 14 saved successfully.
# Audio file 15 saved successfully.
# Audio file 16 saved successfully.
# Audio file 17 saved successfully.
# Audio file 18 saved successfully.
# Audio file 19 saved successfully.
# Audio file 20 saved successfully.
# Audio file 21 saved successfully.
# Audio file 22 saved successfully.
# Audio file 23 saved successfully.
# Audio file 24 saved successfully.
# Audio file 25 saved successfully.
# Audio file 26 saved successfully.
# Audio file 27 saved successfully.
# Audio file 28 saved successfully.
# Audio file 29 saved successfully.
# Audio file 30 saved successfully.
# Audio file 31 saved successfully.
# Audio file 32 saved successfully.
# Audio file 33 saved successfully.
# Audio file 34 saved successfully.
# Audio file 35 saved successfully.
# Audio file 36 saved successfully.
# Audio file 37 saved successfully.
# Audio file 38 saved successfully.
# Audio file 39 saved successfully.
# Audio file 40 saved successfully.
# Audio file 41 saved successfully.
# Audio file 42 saved successfully.
# Audio file 43 saved successfully.
# Audio file 44 saved successfully.
# Audio file 45 saved successfully.
# Audio file 46 saved successfully.
# Audio file 47 saved successfully.
# Audio file 48 saved successfully.
# Audio file 49 saved successfully.
# Audio file 50 saved successfully.
# Audio file 51 saved successfully.
# Audio file 52 saved successfully.
# Audio file 53 saved successfully.
# Audio file 54 saved successfully.
# Audio file 55 saved successfully.
# Audio file 56 saved successfully.
# Audio file 57 saved successfully.
# Audio file 58 saved successfully.
# Audio file 59 saved successfully.
# Audio file 60 saved successfully.
# Audio file 61 saved successfully.
# Audio file 62 saved successfully.
# Audio file 63 saved successfully.
# Audio file 64 saved successfully.
# Audio file 65 saved successfully.
# Audio file 66 saved successfully.
# Audio file 67 saved successfully.
# Audio file 68 saved successfully.
# Audio file 69 saved successfully.
# Audio file 70 saved successfully.
# Audio file 71 saved successfully.
# Audio file 72 saved successfully.
# Audio file 73 saved successfully.
# Audio file 74 saved successfully.
# Audio file 75 saved successfully.
# Audio file 76 saved successfully.
# Audio file 77 saved successfully.
# Audio file 78 saved successfully.
# Audio file 79 saved successfully.
# Audio file 80 saved successfully.
# Audio file 81 saved successfully.
# Audio file 82 saved successfully.
# Audio file 83 saved successfully.
# Audio file 84 saved successfully.
# Audio file 85 saved successfully.
# Audio file 86 saved successfully.
# Audio file 87 saved successfully.
# Audio file 88 saved successfully.
# Audio file 89 saved successfully.
# Audio file 90 saved successfully.
# Audio file 91 saved successfully.
# Audio file 92 saved successfully.
# Audio file 93 saved successfully.
# Audio file 94 saved successfully.
# Audio file 95 saved successfully.
# Audio file 96 saved successfully.
# Audio file 97 saved successfully.
# Audio file 98 saved successfully.
# Audio file 99 saved successfully.
# Audio file 100 saved successfully.
# Audio file 101 saved successfully.
# Audio file 102 saved successfully.
# Audio file 103 saved successfully.
# Audio file 104 saved successfully.
# Audio file 105 saved successfully.
# Audio file 106 saved successfully.
# Audio file 107 saved successfully.
# Audio file 108 saved successfully.
# Audio file 109 saved successfully.
# Audio file 110 saved successfully.
# Audio file 111 saved successfully.
# Audio file 112 saved successfully.
# Audio file 113 saved successfully.
# Audio file 114 saved successfully.
# Retry with next API key due to status code: 401
# Audio file 115 saved successfully.
# Audio file 116 saved successfully.
# Audio file 117 saved successfully.
# Retry with next API key due to status code: 401
# Audio file 118 saved successfully.
# Retry with next API key due to status code: 401
# Audio file 119 saved successfully.
# Audio file 120 saved successfully.
# Retry with next API key due to status code: 401
# Audio file 121 saved successfully.
# Audio file 122 saved successfully.
# Retry with next API key due to status code: 401
# Audio file 123 saved successfully.
# Retry with next API key due to status code: 401
# Audio file 124 saved successfully.
# Audio file 125 saved successfully.
# Retry with next API key due to status code: 401
# Audio file 126 saved successfully.
# Retry with next API key due to status code: 401
# Audio file 127 saved successfully.
# Audio file 128 saved successfully.
# Retry with next API key due to status code: 401
# Audio file 129 saved successfully.
# Retry with next API key due to status code: 401
# Audio file 130 saved successfully.
# Retry with next API key due to status code: 401
# Audio file 131 saved successfully.
# Retry with next API key due to status code: 401
# Audio file 132 saved successfully.
# Retry with next API key due to status code: 401
# Audio file 133 saved successfully.
# Retry with next API key due to status code: 401
# Audio file 134 saved successfully.
# Retry with next API key due to status code: 401
# Audio file 135 saved successfully.
# Retry with next API key due to status code: 401
# Audio file 136 saved successfully.
# Retry with next API key due to status code: 401
# Audio file 137 saved successfully.
# Retry with next API key due to status code: 401
# Audio file 138 saved successfully.
# Retry with next API key due to status code: 401
# Audio file 139 saved successfully.
# Retry with next API key due to status code: 401
# Audio file 140 saved successfully.
# Retry with next API key due to status code: 401
# Audio file 141 saved successfully.
# Retry with next API key due to status code: 401
# Audio file 142 saved successfully.
# Retry with next API key due to status code: 401
# Audio file 143 saved successfully.
# Retry with next API key due to status code: 401
# Audio file 144 saved successfully.
# Retry with next API key due to status code: 401
# Audio file 145 saved successfully.
# Retry with next API key due to status code: 401
# Audio file 146 saved successfully.
# Retry with next API key due to status code: 401
# Audio file 147 saved successfully.
# Retry with next API key due to status code: 401
# Audio file 148 saved successfully.
# Retry with next API key due to status code: 401
# Audio file 149 saved successfully.
# Retry with next API key due to status code: 401
# Audio file 150 saved successfully.
# Retry with next API key due to status code: 401
# Audio file 151 saved successfully.
# Retry with next API key due to status code: 401
# Audio file 152 saved successfully.
# Retry with next API key due to status code: 401
# Audio file 153 saved successfully.
# Retry with next API key due to status code: 401
# Audio file 154 saved successfully.
# Retry with next API key due to status code: 401
# Audio file 155 saved successfully.
# Retry with next API key due to status code: 401
# Audio file 156 saved successfully.
# Retry with next API key due to status code: 401
# Audio file 157 saved successfully.
# Retry with next API key due to status code: 401
# Audio file 158 saved successfully.
# Retry with next API key due to status code: 401
# Audio file 159 saved successfully.
# Retry with next API key due to status code: 401
# Audio file 160 saved successfully.
# Retry with next API key due to status code: 401
# Audio file 161 saved successfully.
# Retry with next API key due to status code: 401
# Audio file 162 saved successfully.
# Retry with next API key due to status code: 401
# Audio file 163 saved successfully.
# Retry with next API key due to status code: 401
# Audio file 164 saved successfully.
# Retry with next API key due to status code: 401
# Audio file 165 saved successfully.
# Retry with next API key due to status code: 401
# Audio file 166 saved successfully.
# Retry with next API key due to status code: 401
# Audio file 167 saved successfully.
# Retry with next API key due to status code: 401
# Audio file 168 saved successfully.
# Retry with next API key due to status code: 401
# Audio file 169 saved successfully.
# Retry with next API key due to status code: 401
# Audio file 170 saved successfully.
# Retry with next API key due to status code: 401
# Audio file 171 saved successfully.
# Retry with next API key due to status code: 401
# Audio file 172 saved successfully.
# Retry with next API key due to status code: 401
# Audio file 173 saved successfully.
# Retry with next API key due to status code: 401
# Audio file 174 saved successfully.
# Retry with next API key due to status code: 401
# Audio file 175 saved successfully.
# Retry with next API key due to status code: 401
# Audio file 176 saved successfully.
# Retry with next API key due to status code: 401
# Audio file 177 saved successfully.
# Retry with next API key due to status code: 401
# Audio file 178 saved successfully.
# Retry with next API key due to status code: 401
# Audio file 179 saved successfully.
# Retry with next API key due to status code: 401
# Audio file 180 saved successfully.
# Retry with next API key due to status code: 401
# Audio file 181 saved successfully.
# Retry with next API key due to status code: 401
# Audio file 182 saved successfully.
# Retry with next API key due to status code: 401
# Audio file 183 saved successfully.
# Retry with next API key due to status code: 401
# Audio file 184 saved successfully.
# Retry with next API key due to status code: 401
# Audio file 185 saved successfully.
# Retry with next API key due to status code: 401
# Audio file 186 saved successfully.
# Retry with next API key due to status code: 401
# Audio file 187 saved successfully.
# Retry with next API key due to status code: 401
# Audio file 188 saved successfully.
# Retry with next API key due to status code: 401
# Audio file 189 saved successfully.
# Retry with next API key due to status code: 401
# Audio file 190 saved successfully.
# Retry with next API key due to status code: 401
# Audio file 191 saved successfully.
# Retry with next API key due to status code: 401
# Audio file 192 saved successfully.
# Retry with next API key due to status code: 401
# Audio file 193 saved successfully.
# Retry with next API key due to status code: 401
# Audio file 194 saved successfully.
# Retry with next API key due to status code: 401
# Audio file 195 saved successfully.
# Retry with next API key due to status code: 401
# Audio file 196 saved successfully.
# Retry with next API key due to status code: 401
# Audio file 197 saved successfully.
# Retry with next API key due to status code: 401
# Audio file 198 saved successfully.
# Retry with next API key due to status code: 401
# Audio file 199 saved successfully.
# Retry with next API key due to status code: 401
# Audio file 200 saved successfully.
# Retry with next API key due to status code: 401
# Audio file 201 saved successfully.
# Retry with next API key due to status code: 401
# Audio file 202 saved successfully.
# Retry with next API key due to status code: 401
# Audio file 203 saved successfully.
# Retry with next API key due to status code: 401
# Audio file 204 saved successfully.
# Retry with next API key due to status code: 401
# Audio file 205 saved successfully.
# Retry with next API key due to status code: 401
# Audio file 206 saved successfully.
# Retry with next API key due to status code: 401
# Audio file 207 saved successfully.
# Retry with next API key due to status code: 401
# Audio file 208 saved successfully.
# Retry with next API key due to status code: 401
# Audio file 209 saved successfully.
# Retry with next API key due to status code: 401
# Audio file 210 saved successfully.
# Retry with next API key due to status code: 401
# Audio file 211 saved successfully.
# Retry with next API key due to status code: 401
# Audio file 212 saved successfully.
# Retry with next API key due to status code: 401
# Audio file 213 saved successfully.
# Retry with next API key due to status code: 401
# Audio file 214 saved successfully.
# Retry with next API key due to status code: 401
# Audio file 215 saved successfully.
# Retry with next API key due to status code: 401
# Audio file 216 saved successfully.
# Retry with next API key due to status code: 401
# Audio file 217 saved successfully.
# Retry with next API key due to status code: 401
# Audio file 218 saved successfully.
# Retry with next API key due to status code: 401
# Audio file 219 saved successfully.
# Retry with next API key due to status code: 401
# Audio file 220 saved successfully.
# Retry with next API key due to status code: 401
# Audio file 221 saved successfully.
# Retry with next API key due to status code: 401
# Audio file 222 saved successfully.
# Retry with next API key due to status code: 401
# Audio file 223 saved successfully.
# Retry with next API key due to status code: 401
# Audio file 224 saved successfully.
# Retry with next API key due to status code: 401
# Audio file 225 saved successfully.
# Retry with next API key due to status code: 401
# Audio file 226 saved successfully.
# Retry with next API key due to status code: 401
# Audio file 227 saved successfully.
# Retry with next API key due to status code: 401
# Audio file 228 saved successfully.
# Retry with next API key due to status code: 401
# Audio file 229 saved successfully.
# Retry with next API key due to status code: 401
# Audio file 230 saved successfully.
# Retry with next API key due to status code: 401
# Audio file 231 saved successfully.
# Retry with next API key due to status code: 401
# Audio file 232 saved successfully.
# Retry with next API key due to status code: 401
# Audio file 233 saved successfully.
# Retry with next API key due to status code: 401
# Audio file 234 saved successfully.
# Retry with next API key due to status code: 401
# Retry with next API key due to status code: 429
# Audio file 235 saved successfully.
# Retry with next API key due to status code: 401
# Audio file 236 saved successfully.
# Retry with next API key due to status code: 401
# Audio file 237 saved successfully.
# Retry with next API key due to status code: 401
# Audio file 238 saved successfully.
# Retry with next API key due to status code: 401
# Audio file 239 saved successfully.
# Retry with next API key due to status code: 401
# Audio file 240 saved successfully.
# Retry with next API key due to status code: 401
# Audio file 241 saved successfully.
# Retry with next API key due to status code: 401
# Audio file 242 saved successfully.
# Retry with next API key due to status code: 401
# Audio file 243 saved successfully.
# Retry with next API key due to status code: 401
# Audio file 244 saved successfully.
# Retry with next API key due to status code: 401
# Audio file 245 saved successfully.
# Retry with next API key due to status code: 401
# Audio file 246 saved successfully.
# Retry with next API key due to status code: 401
# Audio file 247 saved successfully.
# Retry with next API key due to status code: 401
# Audio file 248 saved successfully.
# Retry with next API key due to status code: 401
# Audio file 249 saved successfully.
# Retry with next API key due to status code: 401
# Audio file 250 saved successfully.
# Retry with next API key due to status code: 401
# Audio file 251 saved successfully.
# Retry with next API key due to status code: 401
# Audio file 252 saved successfully.
# Retry with next API key due to status code: 401
# Audio file 253 saved successfully.
# Retry with next API key due to status code: 401
# Audio file 254 saved successfully.
# Retry with next API key due to status code: 401
# Audio file 255 saved successfully.
# Retry with next API key due to status code: 401
# Audio file 256 saved successfully.
# Retry with next API key due to status code: 401
# Audio file 257 saved successfully.
# Retry with next API key due to status code: 401
# Audio file 258 saved successfully.
# Retry with next API key due to status code: 401
# Audio file 259 saved successfully.
# Retry with next API key due to status code: 401
# Audio file 260 saved successfully.
# Retry with next API key due to status code: 401
# Audio file 261 saved successfully.
# Retry with next API key due to status code: 401
# Audio file 262 saved successfully.
# Retry with next API key due to status code: 401
# Audio file 263 saved successfully.
# Retry with next API key due to status code: 401
# Audio file 264 saved successfully.
# Retry with next API key due to status code: 401
# Audio file 265 saved successfully.
# Retry with next API key due to status code: 401
# Audio file 266 saved successfully.
# Retry with next API key due to status code: 401
# Audio file 267 saved successfully.
# Retry with next API key due to status code: 401
# Audio file 268 saved successfully.
# Retry with next API key due to status code: 401
# Audio file 269 saved successfully.
# Retry with next API key due to status code: 401
# Audio file 270 saved successfully.
# Retry with next API key due to status code: 401
# Audio file 271 saved successfully.
# Retry with next API key due to status code: 401
# Audio file 272 saved successfully.
# Retry with next API key due to status code: 401
# Audio file 273 saved successfully.
# Retry with next API key due to status code: 401
# Audio file 274 saved successfully.
# Retry with next API key due to status code: 401
# Audio file 275 saved successfully.
# Retry with next API key due to status code: 401
# Audio file 276 saved successfully.
# Retry with next API key due to status code: 401
# Audio file 277 saved successfully.
# Retry with next API key due to status code: 401
# Audio file 278 saved successfully.
# Retry with next API key due to status code: 401
# Audio file 279 saved successfully.
# Retry with next API key due to status code: 401
# Audio file 280 saved successfully.
# Retry with next API key due to status code: 401
# Audio file 281 saved successfully.
# Retry with next API key due to status code: 401
# Audio file 282 saved successfully.
# Retry with next API key due to status code: 401
# Audio file 283 saved successfully.
# Retry with next API key due to status code: 401
# Audio file 284 saved successfully.
# Retry with next API key due to status code: 401
# Audio file 285 saved successfully.
# Retry with next API key due to status code: 401
# Audio file 286 saved successfully.
# Retry with next API key due to status code: 401
# Audio file 287 saved successfully.
# Retry with next API key due to status code: 401
# Audio file 288 saved successfully.
# Retry with next API key due to status code: 401
# Audio file 289 saved successfully.
# Retry with next API key due to status code: 401
# Audio file 290 saved successfully.
# Retry with next API key due to status code: 401
# Audio file 291 saved successfully.
# Retry with next API key due to status code: 401
# Audio file 292 saved successfully.
# Retry with next API key due to status code: 401
# Audio file 293 saved successfully.
# Retry with next API key due to status code: 401
# Audio file 294 saved successfully.
# Retry with next API key due to status code: 401
# Audio file 295 saved successfully.
# Retry with next API key due to status code: 401
# Audio file 296 saved successfully.
# Retry with next API key due to status code: 401
# Audio file 297 saved successfully.
# Retry with next API key due to status code: 401
# Audio file 298 saved successfully.
# Retry with next API key due to status code: 401
# Audio file 299 saved successfully.
# Retry with next API key due to status code: 401
# Audio file 300 saved successfully.
# Retry with next API key due to status code: 401
# Audio file 301 saved successfully.
# Retry with next API key due to status code: 401
# Audio file 302 saved successfully.
# Retry with next API key due to status code: 401
# Audio file 303 saved successfully.
# Retry with next API key due to status code: 401
# Audio file 304 saved successfully.
# Retry with next API key due to status code: 401
# Audio file 305 saved successfully.
# Retry with next API key due to status code: 401
# Audio file 306 saved successfully.
# Retry with next API key due to status code: 401
# Audio file 307 saved successfully.
# Retry with next API key due to status code: 401
# Audio file 308 saved successfully.
# Retry with next API key due to status code: 401
# Audio file 309 saved successfully.
# Retry with next API key due to status code: 401
# Audio file 310 saved successfully.
# Retry with next API key due to status code: 401
# Audio file 311 saved successfully.
# Retry with next API key due to status code: 401
# Audio file 312 saved successfully.
# Retry with next API key due to status code: 401
# Audio file 313 saved successfully.
# Retry with next API key due to status code: 401
# Audio file 314 saved successfully.
# Retry with next API key due to status code: 401
# Audio file 315 saved successfully.
# Retry with next API key due to status code: 401
# Audio file 316 saved successfully.
# Retry with next API key due to status code: 401
# Audio file 317 saved successfully.
# Retry with next API key due to status code: 401
# Audio file 318 saved successfully.
# Retry with next API key due to status code: 401
# Audio file 319 saved successfully.
# Retry with next API key due to status code: 401
# Audio file 320 saved successfully.
# Retry with next API key due to status code: 401
# Retry with next API key due to status code: 500
# Audio file 321 saved successfully.
# Retry with next API key due to status code: 401
# Audio file 322 saved successfully.
# Retry with next API key due to status code: 401
# Audio file 323 saved successfully.
# Retry with next API key due to status code: 401
# Audio file 324 saved successfully.
# Retry with next API key due to status code: 401
# Audio file 325 saved successfully.
# Retry with next API key due to status code: 401
# Audio file 326 saved successfully.
# Retry with next API key due to status code: 401
# Audio file 327 saved successfully.
# Retry with next API key due to status code: 401
# Audio file 328 saved successfully.
# Retry with next API key due to status code: 401
# Audio file 329 saved successfully.
# Retry with next API key due to status code: 401
# Audio file 330 saved successfully.
# Retry with next API key due to status code: 401
# Audio file 331 saved successfully.
# Retry with next API key due to status code: 401
# Audio file 332 saved successfully.
# Retry with next API key due to status code: 401
# Audio file 333 saved successfully.
# Retry with next API key due to status code: 401
# Audio file 334 saved successfully.
# Retry with next API key due to status code: 401
# Audio file 335 saved successfully.
# Retry with next API key due to status code: 401
# Audio file 336 saved successfully.

# %%
# combine all the audio files into one
from moviepy.editor import concatenate_audioclips, AudioClip, AudioFileClip

audio_clips = []
try:
    for audioNum, (dialogue, speaker) in enumerate(all_dialogue_lines):
        if speaker in character_id:
            audio_clips.append(AudioFileClip(f"chapter_1/{audioNum+1}-{speaker}.mp3"))
        else:
            print(f"Skipping line {audioNum+1} due to missing character ID.")
except:
    print(f"Audio file {audioNum+1} not found. Skipping.")


# Function to create a silent audio clip of a specified duration
def make_silent_clip(duration):
    # Creating a silent clip. This function generates silence.
    return AudioClip(lambda t: np.zeros(1), duration=duration, fps=44100)

# Duration of the pause in seconds
pause_duration = 0.25

# Create silent clips for pauses
silent_clip = make_silent_clip(pause_duration)

# Insert silent clips between the audio clips
audio_clips_with_pause = [
    clip for pair in zip(
        audio_clips, [silent_clip] * (len(audio_clips) - 1)) for clip in pair] + [audio_clips[-1]]

# Concatenate all clips including the silent ones
final_audio = concatenate_audioclips(audio_clips_with_pause)

final_audio.write_audiofile("chapter1.mp3")
print("Combined audio file saved successfully.")
# Out:
# MoviePy - Writing audio in chapter1.mp3
# MoviePy - Done.
# Combined audio file saved successfully.
